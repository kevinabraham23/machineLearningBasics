# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\kevin\Downloads\Position_Salaries.csv")

# %%
data
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %% [markdown]
# ## Splitting the data

# %%
x = data.iloc[:,1:-1]
y = data.iloc[:,-1]

# %% [markdown]
# x

# %%
y
# Out:
# 0      45000
# 1      50000
# 2      60000
# 3      80000
# 4     110000
# 5     150000
# 6     200000
# 7     300000
# 8     500000
# 9    1000000
# Name: Salary, dtype: int64

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## visualizing the features

# %%
plt.scatter(x,y,color="red")
plt.plot(x,lr.predict(x),color="green")
plt.show()

# %% [markdown]
# ## Polynomial Linear Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree = 4)
x_poly = poly_reg.fit_transform(x)

# %%
x_poly
# Out:
# array([[1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00, 1.600e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01, 8.100e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01, 2.560e+02],
#        [1.000e+00, 5.000e+00, 2.500e+01, 1.250e+02, 6.250e+02],
#        [1.000e+00, 6.000e+00, 3.600e+01, 2.160e+02, 1.296e+03],
#        [1.000e+00, 7.000e+00, 4.900e+01, 3.430e+02, 2.401e+03],
#        [1.000e+00, 8.000e+00, 6.400e+01, 5.120e+02, 4.096e+03],
#        [1.000e+00, 9.000e+00, 8.100e+01, 7.290e+02, 6.561e+03],
#        [1.000e+00, 1.000e+01, 1.000e+02, 1.000e+03, 1.000e+04]])

# %%
PolynomialLR = LinearRegression()

# %%
PolynomialLR.fit(x_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualizing Polynomial Linear Regression

# %% [markdown]
# ## Degree=2

# %%
plt.scatter(x,y,color="red")
plt.plot(x,PolynomialLR.predict(poly_reg.fit_transform(x)),color="blue")
plt.show()

# %% [markdown]
# ## Degree=3

# %%
plt.scatter(x,y,color="red")
plt.plot(x,PolynomialLR.predict(poly_reg.fit_transform(x)),color="blue")
plt.show()

# %% [markdown]
# ## Degree=4

# %%
plt.scatter(x,y,color="red")
plt.plot(x,PolynomialLR.predict(poly_reg.fit_transform(x)),color="blue")
plt.show()
